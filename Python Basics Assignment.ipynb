# %% [markdown]
# 1. Explain the key features of Python that make it a popular choice for programming

# %% [raw]
# Answer -
# . Easy to use and learn. Python has a simple syntax that is easy to learn.
# . Multi-Paradigm. Python supports multiple programming paradigms.
# . Open Source. Python is an open-source language.
# . Large Standard Library.
# . Object-Oriented Programming Language.
# . Dynamically Typed.
# . Large Community Support.
# . Portable.

# %% [markdown]
# 2. Describe the role of predefined keywords in Python and provide examples of how they are used in a
# program0

# %% [raw]
# Answer -
# In Python, predefined keywords are reserved words that have specific meanings within the language's syntax. They cannot be used as variable names, function names, or other identifiers. Keywords define the structure and control flow of a program, ensuring consistent and predictable execution.

# %%
#Examples of Keyword Usage 
age = 20
if age >= 18:  # if is a keyword for conditional execution
        print("You are eligible to vote.")
else:  # else is used with if for alternative execution
        print("You are not eligible yet.")
# Out:
# You are eligible to vote.

# %% [markdown]
# 3. Compare and contrast mutable and immutable objects in Python with examples0

# %% [raw]
# Answer -
#
# Mutable Objects:
#
# Definition: Objects that can be altered after they've been created.
# Examples: Lists, dictionaries, and sets.
# Memory: Generally more efficient in memory as they don't require creating new objects for changes.
# Modification: Modifying a mutable object doesn't change its memory address; the changes are made in place.

# %%
#Example: 

my_list = [1, 2, 3]
my_list[0] = 4 # Modifies the list in place
print(my_list) # Output: [4, 2, 3]
# Out:
# [4, 2, 3]

# %% [raw]
# Immutable Objects:
# Definition: Objects whose value cannot be changed once they are created.
# Examples: Integers, floats, strings, tuples, and frozensets.
# Memory: May use more memory as new objects are created when modifications are needed.
# Modification: Modifying an immutable object creates a new object with the modified value, and any references to the original object remain unchanged.

# %%
#Example:
my_string = "Hello"
    my_string = my_string + " World" # Creates a new string object
    print(my_string) # Output: Hello World

# %% [markdown]
# 4. Discuss the different types of operators in Python and provide examples of how they are used

# %% [raw]
# Answer -
#
# Arithmetic Operators
# These operators perform basic mathematical calculations.
# + (Addition): Adds two operands.
# Example: 5 + 3 results in 8.
# - (Subtraction): Subtracts the second operand from the first.
# Example: 10 - 4 results in 6.
# * (Multiplication): Multiplies two operands.
# Example: 2 * 6 results in 12.
# / (Division): Divides the first operand by the second, returning a floating-point number.
# Example: 20 / 5 results in 4.0.
# // (Floor Division): Divides the first operand by the second and returns the integer part of the result.
# Example: 20 // 5 results in 4.
# % (Modulo): Returns the remainder of the division of the first operand by the second.
# Example: 15 % 4 results in 3.
# `: ` (Exponentiation):** Raises the first operand to the power of the second.
# Example: 3 ** 2 results in 9.
# Comparison Operators
# These operators compare two values and return a boolean result (True or False).
# == (Equal to): Checks if two operands are equal.
# Example: 5 == 5 returns True.
# != (Not equal to): Checks if two operands are not equal.
# Example: 5 != 3 returns True.
# > (Greater than): Checks if the first operand is greater than the second.
# Example: 8 > 3 returns True.
# >= (Greater than or equal to): Checks if the first operand is greater than or equal to the second.
# Example: 10 >= 10 returns True.
# < (Less than): Checks if the first operand is less than the second.
# Example: 4 < 7 returns True.
# <= (Less than or equal to): Checks if the first operand is less than or equal to the second.
# Example: 5 <= 5 returns True.
# Logical Operators
# These operators combine or manipulate boolean values.
# and: Returns True if both operands are True, otherwise returns False.
# Example: True and True returns True.
# or: Returns True if at least one operand is True, otherwise returns False.
# Example: True or False returns True.
# not: Inverts the boolean value of the operand.
# Example: not True returns False.
# Assignment Operators
# These operators assign values to variables.
# = (Assignment):
# Assigns the value on the right side to the variable on the left.
# Example: x = 5 assigns the value 5 to the variable x.
# += (Addition assignment):
# Adds the value on the right side to the current value of the variable and assigns the result back to the variable.
# Example: x += 3 is equivalent to x = x + 3.
# *= (Multiplication assignment):
# Multiplies the current value of the variable by the value on the right side and assigns the result back to the variable.
# Example: x *= 2 is equivalent to x = x * 2.

# %% [markdown]
# 5. Explain the concept of type casting in Python with examples0

# %% [raw]
# Answer -
#
# Type casting in Python, also known as type conversion, is the process of changing a variable's data type from one type to another. It involves converting a value from its current type (e.g., string, integer, float) to a different type (e.g., integer, float, string). Python supports both implicit and explicit type casting.
#
# Implicit Type Casting: This happens automatically when Python converts a data type to another without any explicit instructions from the programmer. For example, if you add an integer and a float, Python will automatically convert the integer to a float before performing the addition.
#
# Examples
#
# x = 5
#    y = 2.5
#    z = x + y  # Python implicitly converts x to float
#    print(z)       # Output: 7.5
#    print(type(z)) # Output: <class 'float'>
#
# Explicit Type Casting: This involves using built-in Python functions like int(), float(), str(), bool(), etc., to manually convert a value from one type to another.
#
# Examples
#
# # Converting a string to an integer
#    num_str = "123"
#    num_int = int(num_str)  # Explicitly convert to int
#    print(num_int)     # Output: 123
#    print(type(num_int)) # Output: <class 'int'>
#
#    # Converting a float to an integer
#    num_float = 3.14
#    num_int = int(num_float)  # Explicitly convert to int (truncates decimal part)
#    print(num_int)     # Output: 3
#    print(type(num_int)) # Output: <class 'int'>
#
#    # Converting an integer to a float
#    num_int = 42
#    num_float = float(num_int) # Explicitly convert to float
#    print(num_float)    # Output: 42.0
#    print(type(num_float)) # Output: <class 'float'>
#
#    # Converting an integer to a string
#    num_int = 5
#    num_str = str(num_int)  # Explicitly convert to string
#    print(num_str)       # Output: 5
#    print(type(num_str)) # Output: <class 'str'>
#
#    # Converting a boolean to an integer
#    bool_val = True
#    int_val = int(bool_val)  # Explicitly convert to int (True becomes 1, False becomes 0)
#    print(int_val)       # Output: 1
#    print(type(int_val)) # Output: <class 'int'>

# %% [markdown]
# 6.  How do conditional statements work in Python? Illustrate with examples0

# %% [raw]
# Conditional statements in Python, like if, elif, and else, allow you to execute different code blocks based on whether a condition is true or false. The basic structure involves an if statement with a condition, followed by optional elif statements for checking multiple conditions, and an else statement to handle the case when none of the preceding conditions are true.
#
# 1. The if Statement:
# The if statement checks a condition and executes the code block below it only if the condition is true.
# Example:
# Python
#
#         age = 20
#         if age >= 18:
#             print("You can vote!")
# 2. The if-else Statement:
# The if-else statement executes one code block if the condition is true and another code block if the condition is false.
# Example:
# Python
#
#         x = 5
#         if x > 10:
#             print("x is greater than 10")
#         else:
#             print("x is not greater than 10")
# 3. The if-elif-else Statement:
# The if-elif-else statement allows you to check multiple conditions in sequence.
# The elif (else if) statement allows you to check an additional condition if the previous conditions are false.
# The else statement is executed if none of the previous conditions are true.
# Example:
# Python
#
#         score = 75
#         if score >= 90:
#             print("Grade A")
#         elif score >= 80:
#             print("Grade B")
#         elif score >= 70:
#             print("Grade C")
#         else:
#             print("Grade D")
# 4. Nesting Conditional Statements:
# You can nest conditional statements within other conditional statements to create more complex logic.
# Example:
# Python
#
#         number = 25
#         if number > 10:
#             if number % 2 == 0:
#                 print("Number is greater than 10 and even")
#             else:
#                 print("Number is greater than 10 and odd")
#         else:
#             print("Number is not greater than 10")

# %% [markdown]
# 7. Describe the different types of loops in Python and their use cases with examples.

# %% [raw]
# Python has two main types of loops: for loops and while loops. For loops are used for iterating over a sequence, while while loops repeat a block of code as long as a condition is true. Nested loops are also possible, where a loop is placed inside another loop.
#
# 1. For Loop:
# Purpose: Iterates over a sequence (e.g., lists, tuples, strings) or a range of numbers.
# Syntax: for loop_variable in sequence:
# Example:
# Python
#
#     fruits = ["apple", "banana", "cherry"]
#     for fruit in fruits:
#         print(fruit)
# This code iterates through the fruits list, printing each fruit name.
#
# 2. While Loop:
# Purpose: Repeats a block of code as long as a condition is true.
# Syntax: while condition:
# Example:
# Python
#
#     count = 0
#     while count < 5:
#         print(count)
#         count += 1
# This code prints numbers from 0 to 4 because the loop continues as long as count is less than 5.
